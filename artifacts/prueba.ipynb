# %%
from utils.common_functions import read_yaml

r = read_yaml("config/config.yaml")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File D:\IMPA\MLOps\1_Hotel\utils\common_functions.py:12, in read_yaml(file_path)
#      11 if not os.path.exists(file_path):
# ---> 12     raise FileNotFoundError(f"YAML file not found at given path")
#      14 with open(file_path, "r") as yaml_file:
#
# FileNotFoundError: YAML file not found at given path
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 3
#       1 from utils.common_functions import read_yaml
# ----> 3 r = read_yaml("config/config.yaml")
#
# File D:\IMPA\MLOps\1_Hotel\utils\common_functions.py:20, in read_yaml(file_path)
#      18 except Exception as e:
#      19     logger.error(f"Error reading YAML file")
# ---> 20     raise CustomException("Failed to read YAML file", e)
#
# ...

# %%
from utils.common_functions import read_yaml
